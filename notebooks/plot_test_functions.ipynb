# %% [markdown]
# # Classical Test Functions for Optimization
#
# Author: Ziad Ghauch

# %%
import numpy as np
import matplotlib.pyplot as plt
from optTEST.single_objective_opt import SingleObjective
from optTEST.constrained_opt import ConstrainedObjective
from optTEST.multi_objective_opt import MultiObjective
from optTEST.utils import *

# %% [markdown]
# ## Single-Objective Optimization

# %%
print (SingleObjective.__doc__)
print ('List of function' + str(SingleObjective.tests))
# Out:
#  Single-objective optimization class
#
#     Test functions with single-objective optimization
# List of function['Rastrigin', 'Ackley', 'Sphere', 'Rosenbrock', 'Beale', 'Goldstein-Price', 'Booth', 'Bukin', 'Matyas', 'Levi', 'Himmelblau', 'Three-hump-camel', 'Easom', 'Cross-in-tray', 'Eggholder', 'Holder-table', 'McCormik', 'Schaffer1', 'Schaffer2', 'Styblinski–Tang']

# %%
PlotsFunctions(100,[-5.,5.],[-5.,5.],'Ackley').plot_contour_2d()

# %%
PlotsFunctions(100,[-10.,10.],[-10.,10.],'Sphere').plot_contour_2d()

# %%
PlotsFunctions(100,[-4.5,4.5],[-4.5,4.5],'Beale').plot_contour_2d()

# %%
PlotsFunctions(100,[-2.,2.],[-2.,2.],'Goldstein-Price').plot_contour_2d()

# %%
PlotsFunctions(100,[-10.,10.],[-10.,10.],'Booth').plot_contour_2d()

# %%
PlotsFunctions(100,[-15.,-5.],[-3.,3.],'Bukin').plot_contour_2d()

# %%
PlotsFunctions(100,[-10.,10.],[-10.,10.],'Matyas').plot_contour_2d()

# %%
PlotsFunctions(100,[-10.,10.],[-10.,10.],'Levi').plot_contour_2d()

# %%
PlotsFunctions(100,[-5.,5.],[-5.,5.],'Himmelblau').plot_contour_2d()

# %%
PlotsFunctions(100,[-5.,5.],[-5.,5.],'Three-hump-camel').plot_contour_2d()

# %%
PlotsFunctions(100,[-100.,100.],[-100.,100.],'Easom').plot_contour_2d()

# %%
PlotsFunctions(100,[-10.,10.],[-10.,10.],'Cross-in-tray').plot_contour_2d()

# %%
PlotsFunctions(100,[-512.,512.],[-512.,512.],'Eggholder').plot_contour_2d()

# %%
PlotsFunctions(100,[-10.,10.],[-10.,10.],'Holder-table').plot_contour_2d()

# %%
PlotsFunctions(100,[-1.5,4.],[-3.,4.],'McCormik').plot_contour_2d()

# %%
PlotsFunctions(100,[-100,100.],[-100.,100.],'Schaffer1').plot_contour_2d()

# %%
PlotsFunctions(100,[-100,100.],[-100.,100.],'Schaffer2').plot_contour_2d()

# %%
PlotsFunctions(100,[-5.,5.],[-5.,5.],'Styblinski–Tang').plot_contour_2d()

# %% [markdown]
# ## Multi-Objective Optimization

# %%
print (MultiObjective.__doc__)
print (MultiObjective.tests)
# Out:
#  Multi-objective optimization
#
#     Test functions with multi-objective optimization
# ['Binh-Corn', 'Chankong-Haimes', 'Fonseca-Fleming', 'Kursawe', 'Schaffer1', 'Schaffer2', 'Poloni', 'Osyczka-Kundu', 'Viennet']

# %% [markdown]
# ## Constrained Optimization

# %%
print (ConstrainedObjective.__doc__)
print (ConstrainedObjective.tests)
# Out:
#  Constrained objective optimization
#
#     Test functions with constrained optimization
# ['Rosenbrock1', 'Rosenbrock2', 'Mishra', 'Townsend', 'Gomez-Levi', 'Simionescu']

# %%
PlotsFunctions(100,[-1.5,1.5],[-0.5,2.5],'Rosenbrock1').plot_contour_2d()

# %%
PlotsFunctions(100,[-1.5,1.5],[-1.5,1.5],'Rosenbrock2').plot_contour_2d()

# %%
PlotsFunctions(100,[-10.,0.0],[-10.,0.0],'Mishra').plot_contour_2d()

# %%
PlotsFunctions(100,[-2.25,2.25],[-2.5,1.75],'Townsend').plot_contour_2d()

# %%
PlotsFunctions(100,[-1.,0.75],[-1.0,1.0],'Gomez-Levi').plot_contour_2d()

# %%
PlotsFunctions(100,[-1.25,1.25],[-1.25,1.25],'Simionescu').plot_contour_2d()
